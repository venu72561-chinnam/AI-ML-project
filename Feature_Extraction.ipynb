# %% [markdown]
# <a href="https://colab.research.google.com/github/venu72561-chinnam/AI-ML-project/blob/main/Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image= cv2.imread('/content/cells-1872666_1280.jpg')
plt.imshow(image)

# %%
grey_image= cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(grey_image, cmap='gray')

# %%
sift = cv2.SIFT_create()
keypoints, descriptors=sift.detectAndCompute(grey_image, None)

# %%
image_with_keypoints = cv2.drawKeypoints(image, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS, color=(0, 255, 0))

# %%
plt.figure(figsize=(12, 8))

# %%
plt.imshow(cv2.cvtColor(image_with_keypoints, cv2.COLOR_BGR2RGB))

# %%
plt.title("SIFT Feature Keypoints")
# Out:
# Text(0.5, 1.0, 'SIFT Feature Keypoints')

# %%
plt.axis('off')
plt.show()

# %%
orb=cv2.ORB_create(nfeatures=1000)

# %%
keypoint_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# %%
# Display Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(keypoint_image, cv2.COLOR_BGR2RGB))
plt.title("ORB Keypoints")
plt.axis("off")
plt.show()

# %%
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 904
# Descriptor shape: (904, 128)

# %%
brisk = cv2.BRISK_create()

# %%
keypoints, descriptors = orb.detectAndCompute(grey_image, None)
keypoints, descriptors = brisk.detectAndCompute(grey_image, None)

# %%
keypoint_image=cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# %%
# Display Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(keypoint_image, cv2.COLOR_BGR2RGB))
plt.title("brisk keypoints")
plt.axis("off")
plt.show()

# %%
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 624
# Descriptor shape: (624, 64)

# %%
akaze = cv2.AKAZE_create()

# %%
keypoints, descriptors = akaze.detectAndCompute(grey_image, None)

# %%
keypoint_image = cv2.drawKeypoints(image, keypoints, None, color=(0, 255, 0), flags=0)

# %%
# Display Image
plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(keypoint_image, cv2.COLOR_BGR2RGB))
plt.title("azake keypoints")
plt.axis("off")
plt.show()

# %%
print(f"Number of keypoints detected: {len(keypoints)}")
print(f"Descriptor shape: {descriptors.shape}")
# Out:
# Number of keypoints detected: 945
# Descriptor shape: (945, 61)
